# %%
import sys
import matplotlib.pyplot as plt
import pandas as pd

sys.path.append('C:/Users/tillm/program_projects/wti-brent-risk-model/src')

# %%
wti = pd.read_csv('../data/processed/wti/yfinance/_1d_2020-07-07_to_2025-07-07_prices.csv',
                  parse_dates=True, 
                  index_col=0)

brent = pd.read_csv('../data/processed/brent/yfinance/_1d_2020-07-07_to_2025-07-07_prices.csv',
                    parse_dates=True, 
                    index_col=0)

# %% [markdown]
# ### Spread

# %%
wti.head()
# Out:
#                 Close
# 2020-07-07  40.619999
# 2020-07-08  40.900002
# 2020-07-09  39.619999
# 2020-07-10  40.549999
# 2020-07-13  40.099998

# %%
from features.compute_spread import compute_spread

wti_brent_spread = compute_spread(wti, brent)

# %%
plt.figure(figsize=(12, 6))
plt.plot(wti_brent_spread.index, wti_brent_spread['Spread'], label='Spread', color='green')
plt.title('WTI vs Brent Spread Over Time')
plt.xlabel('Date')
plt.ylabel('Spread (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Rolling Statistics

# %%
from utils.plotting import plot_rolling_statistics

plot_rolling_statistics(wti_brent_spread['Spread'], window=30)
